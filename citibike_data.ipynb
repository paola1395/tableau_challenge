# %%
# Import dependencies
import pandas as pd

# %%
# Import data files
april_2019 = "2019_citibike_data/april_2019.csv"
july_2019 = "2019_citibike_data/july_2019.csv"
oct_2019 = "2019_citibike_data/oct_2019.csv"

april_2020 = "2020_citibike_data/april_2020.csv"
july_2020 = "2020_citibike_data/july_2020.csv"
oct_2020 = "2020_citibike_data/oct_2020.csv"

# %%
april_19 = pd.read_csv(april_2019, encoding="ISO-8859-1")
april_19.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           107  2019-04-01 07:48:04.7540  2019-04-01 07:49:52.3590
# 1           493  2019-04-01 12:41:09.6540  2019-04-01 12:49:23.0290
# 2           512  2019-04-01 14:27:07.9400  2019-04-01 14:35:40.9370
# 3           196  2019-04-01 15:07:38.1510  2019-04-01 15:10:54.6260
# 4           463  2019-04-01 16:19:24.6940  2019-04-01 16:27:08.6450
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3184       Paulus Hook
# ...

# %%
apr_years = pd.DataFrame(april_19["birth year"])
apr_years
# Out:
#        birth year
# 0            1966
# 1            1990
# 2            1987
# 3            1989
# 4            1995
# ...           ...
# 33051        1983
# 33052        1988
# 33053        1991
# 33054        1991
# 33055        1988
#
# [33056 rows x 1 columns]

# %%
apr_age = pd.DataFrame(2019 - apr_years["birth year"])
apr_age
# Out:
#        birth year
# 0              53
# 1              29
# 2              32
# 3              30
# 4              24
# ...           ...
# 33051          36
# 33052          31
# 33053          28
# 33054          28
# 33055          31
#
# [33056 rows x 1 columns]

# %%
apr_age_count = pd.DataFrame(apr_age['birth year']).value_counts()
apr_age_count.head(10)
# Out:
# birth year
# 50            2116
# 32            2044
# 31            1961
# 33            1770
# 30            1669
# 29            1526
# 28            1374
# 35            1293
# 38            1273
# 34            1269
# dtype: int64

# %%
july_19 = pd.read_csv(july_2019, encoding="ISO-8859-1")
july_19.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1793  2019-07-01 00:00:36.6150  2019-07-01 00:30:30.5940
# 1           434  2019-07-01 00:02:54.6150  2019-07-01 00:10:09.0370
# 2           251  2019-07-01 00:03:27.5670  2019-07-01 00:07:38.6080
# 3           636  2019-07-01 00:03:56.1690  2019-07-01 00:14:32.4180
# 4           623  2019-07-01 00:04:16.2060  2019-07-01 00:14:40.0500
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3206            Hilltop               40.731169
# 2              3186      Grove St PATH               40.719586
# 3              3206            Hilltop               40.731169
# 4              3206            Hilltop               40.731169
#
#    start station longitude  end station id     end station name  \
# 0               -74.043117            3198     Heights Elevator
# ...

# %%
jul_years = pd.DataFrame(april_19["birth year"])
jul_age = pd.DataFrame(2019 - jul_years["birth year"])
jul_age_count = pd.DataFrame(jul_age['birth year']).value_counts()
jul_age_count.head(10)
# Out:
# birth year
# 50            2116
# 32            2044
# 31            1961
# 33            1770
# 30            1669
# 29            1526
# 28            1374
# 35            1293
# 38            1273
# 34            1269
# dtype: int64

# %%
apr_jul = pd.concat([april_19, july_19])
apr_jul.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           107  2019-04-01 07:48:04.7540  2019-04-01 07:49:52.3590
# 1           493  2019-04-01 12:41:09.6540  2019-04-01 12:49:23.0290
# 2           512  2019-04-01 14:27:07.9400  2019-04-01 14:35:40.9370
# 3           196  2019-04-01 15:07:38.1510  2019-04-01 15:10:54.6260
# 4           463  2019-04-01 16:19:24.6940  2019-04-01 16:27:08.6450
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3184       Paulus Hook
# ...

# %%
oct_19 = pd.read_csv(oct_2019, encoding="ISO-8859-1")
oct_19.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           892  2019-10-01 00:20:05.0140  2019-10-01 00:34:57.3800
# 1           374  2019-10-01 00:43:48.8790  2019-10-01 00:50:03.8190
# 2           170  2019-10-01 01:35:51.8630  2019-10-01 01:38:42.5470
# 3           946  2019-10-01 02:55:53.4000  2019-10-01 03:11:40.2710
# 4           517  2019-10-01 03:10:16.1290  2019-10-01 03:18:53.6350
#
#    start station id start station name  start station latitude  \
# 0              3275     Columbus Drive               40.718355
# 1              3211         Newark Ave               40.721525
# 2              3194    McGinley Square               40.725340
# 3              3272       Jersey & 3rd               40.723332
# 4              3206            Hilltop               40.731169
#
#    start station longitude  end station id            end station name  \
# 0               -74.038914            3280                 Astor Place
# ...

# %%
oct_years = pd.DataFrame(oct_19["birth year"])
oct_age = pd.DataFrame(2019 - oct_years["birth year"])
oct_age_count = pd.DataFrame(oct_age['birth year']).value_counts()
oct_age_count.head(10)
# Out:
# birth year
# 30            2534
# 50            2368
# 32            2220
# 33            2154
# 31            2098
# 35            1970
# 29            1962
# 28            1835
# 36            1671
# 34            1616
# dtype: int64

# %%
combined_19 = pd.concat([apr_jul, oct_19])
combined_19.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           107  2019-04-01 07:48:04.7540  2019-04-01 07:49:52.3590
# 1           493  2019-04-01 12:41:09.6540  2019-04-01 12:49:23.0290
# 2           512  2019-04-01 14:27:07.9400  2019-04-01 14:35:40.9370
# 3           196  2019-04-01 15:07:38.1510  2019-04-01 15:10:54.6260
# 4           463  2019-04-01 16:19:24.6940  2019-04-01 16:27:08.6450
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3184       Paulus Hook
# ...

# %%
april_20 = pd.read_csv(april_2020, encoding="ISO-8859-1")
april_20.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1437  2020-04-01 01:06:20.6300  2020-04-01 01:30:17.9680
# 1           264  2020-04-01 05:02:42.0570  2020-04-01 05:07:06.1260
# 2           254  2020-04-01 06:20:28.1190  2020-04-01 06:24:42.1380
# 3           429  2020-04-01 06:33:30.5170  2020-04-01 06:40:40.1990
# 4           805  2020-04-01 06:38:32.9220  2020-04-01 06:51:58.2050
#
#    start station id start station name  start station latitude  \
# 0              3678      Fairmount Ave               40.725726
# 1              3207        Oakland Ave               40.737604
# 2              3678      Fairmount Ave               40.725726
# 3              3195            Sip Ave               40.730897
# 4              3193       Lincoln Park               40.724605
#
#    start station longitude  end station id end station name  \
# 0               -74.071959            3678    Fairmount Ave
# ...

# %%
july_20 = pd.read_csv(july_2020, encoding="ISO-8859-1")
july_20.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          2333  2020-07-01 00:23:19.8220  2020-07-01 01:02:13.2980
# 1          1203  2020-07-01 00:27:45.2420  2020-07-01 00:47:49.1960
# 2           786  2020-07-01 00:34:17.8680  2020-07-01 00:47:24.6310
# 3          1488  2020-07-01 00:51:07.5310  2020-07-01 01:15:56.0200
# 4          2682  2020-07-01 00:51:16.3880  2020-07-01 01:35:58.4590
#
#    start station id          start station name  start station latitude  \
# 0              3694              Jackson Square               40.711130
# 1              3791  Hoboken Ave at Monmouth St               40.735208
# 2              3792  Columbus Dr at Exchange Pl               40.716870
# 3              3677                Glenwood Ave               40.727551
# 4              3191                    Union St               40.718211
#
#    start station longitude  end station id       end station name  \
# ...

# %%
aprjul_20 = pd.concat([april_20, july_20])
aprjul_20.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1437  2020-04-01 01:06:20.6300  2020-04-01 01:30:17.9680
# 1           264  2020-04-01 05:02:42.0570  2020-04-01 05:07:06.1260
# 2           254  2020-04-01 06:20:28.1190  2020-04-01 06:24:42.1380
# 3           429  2020-04-01 06:33:30.5170  2020-04-01 06:40:40.1990
# 4           805  2020-04-01 06:38:32.9220  2020-04-01 06:51:58.2050
#
#    start station id start station name  start station latitude  \
# 0              3678      Fairmount Ave               40.725726
# 1              3207        Oakland Ave               40.737604
# 2              3678      Fairmount Ave               40.725726
# 3              3195            Sip Ave               40.730897
# 4              3193       Lincoln Park               40.724605
#
#    start station longitude  end station id end station name  \
# 0               -74.071959            3678    Fairmount Ave
# ...

# %%
oct_20 = pd.read_csv(oct_2020, encoding="ISO-8859-1")
oct_20.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           156  2020-10-01 00:02:40.2600  2020-10-01 00:05:17.0140
# 1           143  2020-10-01 00:02:53.5020  2020-10-01 00:05:16.9650
# 2           305  2020-10-01 00:04:31.3160  2020-10-01 00:09:36.3840
# 3          1097  2020-10-01 00:05:18.3680  2020-10-01 00:23:36.1240
# 4           277  2020-10-01 00:09:17.5990  2020-10-01 00:13:55.5150
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3186      Grove St PATH               40.719586
# 2              3273       Manila & 1st               40.721651
# 3              3199       Newport Pkwy               40.728745
# 4              3199       Newport Pkwy               40.728745
#
#    start station longitude  end station id     end station name  \
# 0               -74.043117            3270      Jersey & 6th St
# ...

# %%
combined_20 = pd.concat([aprjul_20, oct_20])
combined_20.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1437  2020-04-01 01:06:20.6300  2020-04-01 01:30:17.9680
# 1           264  2020-04-01 05:02:42.0570  2020-04-01 05:07:06.1260
# 2           254  2020-04-01 06:20:28.1190  2020-04-01 06:24:42.1380
# 3           429  2020-04-01 06:33:30.5170  2020-04-01 06:40:40.1990
# 4           805  2020-04-01 06:38:32.9220  2020-04-01 06:51:58.2050
#
#    start station id start station name  start station latitude  \
# 0              3678      Fairmount Ave               40.725726
# 1              3207        Oakland Ave               40.737604
# 2              3678      Fairmount Ave               40.725726
# 3              3195            Sip Ave               40.730897
# 4              3193       Lincoln Park               40.724605
#
#    start station longitude  end station id end station name  \
# 0               -74.071959            3678    Fairmount Ave
# ...

# %%
# Combine all of the combined DFs
citibike_data = pd.concat([combined_19, combined_20])
citibike_data.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           107  2019-04-01 07:48:04.7540  2019-04-01 07:49:52.3590
# 1           493  2019-04-01 12:41:09.6540  2019-04-01 12:49:23.0290
# 2           512  2019-04-01 14:27:07.9400  2019-04-01 14:35:40.9370
# 3           196  2019-04-01 15:07:38.1510  2019-04-01 15:10:54.6260
# 4           463  2019-04-01 16:19:24.6940  2019-04-01 16:27:08.6450
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3184       Paulus Hook
# ...

# %%
# Export to csv
citibike_data.to_csv("citibike_data.csv", index=False)
